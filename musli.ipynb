# %% [markdown]
# План реализации:
# 1. Выгрузить все что только можно:
#     - продажи
#     - возвраты
#     - выписку
# 2. Пололжить это все в таблицы SQL

# %% [markdown]
# ----

# %% [markdown]
# Вопросы к бухгалтеру:
# - Как связывается оплата от магазина с накладными?
# - Как посмотреть все накладные?
# - Как в 1с добавляется оплата накладных? Руками? Как долго?
# - Почему не видно не оплаченные счета?
# - Выдать пользователя со всеми правами можем?
#
# Вопросы к управляющим:
# - Хранятся ли старые отгруженные накладные?
# - Есть ли накладные по приемке и отгрузке сырья? Если ли накладные по производству?
# - может есть отчеты о производстве? или хотя бы старые накладные
# - по второму цеху есть ли какие-нибудь записи? отцифровки? накладные/отчеты?

# %% [markdown]
# ----

# %% [markdown]
# Идеи:

# %% [markdown]
# 1. может быть можно сделать так: посмотреть сколько было продано и какого товара, посчитать сколько это себестоимости (с учетом энергии). по идее оставшиеся деньги из расходов должны быть как раз деньгами которые были потрачены на другой цех (а он в свою очередь отдает деньги в ЗП налом и оплату кредитов)
#
# 2. Можно посмотреть по каким реализациям/накладным есть все поступления. И
#
# 3. Можно посмотреть и проверить какие поступления учтены в 1с таблицах, а какие нет и понять какие не учеты и почему
#
# 4. Посмотреть какие есть траты и с чем они связаны

# %% [markdown]
# ----

# %% [markdown]
# Нужно дляя финансового аудита 1:
# 1. Выписка по счету
# 2. Произведенный товар
# 3. Проданный товар
# 4. Возвраты (?)
# 5. Себестоимость производства
#
# Выгрузить продажи номекулатуры по контрагентам
#
#
# Действия
# 1. По выписке нужно проклассифицировать доход/расход
# 2. Собрать одну таблицу где будет как в выписке каждый приход/расход с классификацией. Возможно стоит сделать сразу скрипт для этого
